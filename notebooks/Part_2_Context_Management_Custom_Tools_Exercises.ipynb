# %% [markdown]
# # Part 2: Context Management & Custom Agent Tools
# ### Building Custom Tools for Agent Capabilities
#
# <div style="background: linear-gradient(135deg, #581c87 0%, #7c3aed 100%);
#             backdrop-filter: blur(10px);
#             border: 1px solid rgba(255,255,255,0.1);
#             padding: 28px;
#             border-radius: 12px;
#             color: white;
#             margin: 0;
#             box-shadow: 0 10px 40px rgba(88,28,135,0.4), 0 2px 12px rgba(124,58,237,0.3);">
#
# <h2 style="margin: 0 0 16px 0; font-size: 1.8em; color: white; font-weight: 700;">
#     ⏱️ Estimated Time: 25 Minutes
# </h2>
#
# <p style="margin: 0 0 12px 0; font-size: 1.1em; line-height: 1.7; opacity: 0.95;">
#     Explore MCP infrastructure, learn intelligent context management, and build custom Aurora PostgreSQL tools
#     with Strands SDK that reduce token usage while maintaining conversation quality.
# </p>
#
# <div style="background: rgba(255,255,255,0.15);
#             padding: 18px;
#             border-radius: 10px;
#             margin-top: 18px;">
#     <p style="margin: 0 0 12px 0; font-size: 1.02em; color: white; line-height: 1.7;">
#         <strong>Section 0: MCP Foundation (5 min)</strong><br>
#         Explore Aurora PostgreSQL MCP server with Amazon Q
#     </p>
#     <p style="margin: 0 0 12px 0; font-size: 1.02em; color: white; line-height: 1.7;">
#         <strong>Section 1: Context Management (7 min)</strong><br>
#         Token budgeting + Intelligent pruning strategies
#     </p>
#     <p style="margin: 0; font-size: 1.02em; color: white; line-height: 1.7;">
#         <strong>Section 2: Custom Agent Tools (13 min)</strong><br>
#         Build Aurora tools → Test with agents → Cost optimization
#     </p>
# </div>
#
# <p style="margin: 18px 0 0 0; font-size: 0.98em; color: white; opacity: 0.9;">
#     <strong>🎯 What You'll Build:</strong> Custom tools that add business intelligence on top of MCP infrastructure
# </p>
#
# </div>

# %% [markdown]
# ---
#
# ### 📖 Notebook Guide
#
# <div style="background: rgba(88,28,135,0.08);
#             padding: 20px;
#             border-radius: 12px;
#             margin: 0;
#             border: 1px solid rgba(124,58,237,0.2);">
#
# <h4 style="margin: 0 0 16px 0; color: #c4b5fd; font-size: 1.1em; font-weight: 600;">
#     Cell Type Legend
# </h4>
#
# <!-- SETUP CELL -->
# <div style="background: linear-gradient(135deg, rgba(245,158,11,0.18) 0%, rgba(217,119,6,0.12) 100%);
#             backdrop-filter: blur(8px);
#             border: 1px solid rgba(245,158,11,0.3);
#             border-left: 5px solid #f59e0b;
#             padding: 16px 18px;
#             border-radius: 8px;
#             margin: 12px 0;
#             box-shadow: 0 3px 10px rgba(245,158,11,0.25);">
#     <strong style="color: #ffffff; font-size: 1.05em; display: block; margin-bottom: 6px;">
#         ⚠️ SETUP CELL - RUN THIS FIRST
#     </strong>
#     <span style="color: #ffffff; font-size: 0.95em; line-height: 1.6; opacity: 0.95;">
#         Pre-written code that must be executed. No changes needed.
#     </span>
# </div>
#
# <!-- TODO CELL -->
# <div style="background: linear-gradient(135deg, rgba(88,28,135,0.18) 0%, rgba(124,58,237,0.12) 100%);
#             backdrop-filter: blur(8px);
#             border: 1px solid rgba(124,58,237,0.3);
#             border-left: 5px solid #7c3aed;
#             padding: 16px 18px;
#             border-radius: 8px;
#             margin: 12px 0;
#             box-shadow: 0 3px 10px rgba(88,28,135,0.25);">
#     <strong style="color: #ffffff; font-size: 1.05em; display: block; margin-bottom: 6px;">
#         📝 TODO - YOUR CODE HERE
#     </strong>
#     <span style="color: #ffffff; font-size: 0.95em; line-height: 1.6; opacity: 0.95;">
#         Complete the marked sections. Follow hints and examples provided.
#     </span>
# </div>
#
# <!-- CODE PROVIDED CELL -->
# <div style="background: linear-gradient(135deg, rgba(40,167,69,0.18) 0%, rgba(34,139,34,0.12) 100%);
#             backdrop-filter: blur(8px);
#             border: 1px solid rgba(40,167,69,0.3);
#             border-left: 5px solid #28a745;
#             padding: 16px 18px;
#             border-radius: 8px;
#             margin: 12px 0;
#             box-shadow: 0 3px 10px rgba(40,167,69,0.25);">
#     <strong style="color: #ffffff; font-size: 1.05em; display: block; margin-bottom: 6px;">
#         ✅ CODE PROVIDED - JUST RUN
#     </strong>
#     <span style="color: #ffffff; font-size: 0.95em; line-height: 1.6; opacity: 0.95;">
#         Complete implementation provided. Run to see results or verify your work.
#     </span>
# </div>
#
# </div>

# %% [markdown]
# ---
# ## ⚙️ Step 0: Select Python Kernel (START HERE!)
# <div style="background: linear-gradient(135deg, rgba(245,158,11,0.18) 0%, rgba(217,119,6,0.18) 100%);
#             backdrop-filter: blur(10px);
#             border: 1px solid rgba(245,158,11,0.35);
#             border-left: 6px solid #f59e0b;
# padding: 24px;
# border-radius: 12px;
# margin: 24px 0;
# box-shadow: 0 8px 20px rgba(245,158,11,0.25);">
# <h4 style="margin: 0 0 16px 0; color: #fbbf24; font-size: 1.25em; font-weight: 600;">
# ⚠️ IMPORTANT FIRST STEP
# </h4>
# <div style="background: linear-gradient(135deg, rgba(245,158,11,0.12) 0%, rgba(217,119,6,0.12) 100%);
# backdrop-filter: blur(10px);
# border: 1px solid rgba(245,158,11,0.3);
# padding: 20px;
# border-radius: 10px;
# box-shadow: 0 2px 8px rgba(245,158,11,0.15);">
# <p style="margin: 0 0 16px 0; color: #e9ecef; line-height: 1.7; font-size: 1.02em;">
# Before running any code, you need to select the correct Python kernel for this workshop:
# </p>
# <ol style="margin: 10px 0 16px 0; padding-left: 25px; color: #e9ecef; line-height: 1.8;">
# <li>Click the kernel selector (top-right corner)</li>
# <li>Select 'Python Environments...' from the dropdown</li>
# <li>Select <strong>"Python 3.13.3 (Global Env)"</strong> from the list</li>
# </ol>
# <p style="margin: 0; color: #fbbf24; font-weight: 600; font-size: 1.02em;">
# ✅ Run the cell below to verify you're using the correct Python version
# </p>
# </div>
# <div style="background: linear-gradient(135deg, rgba(239,68,68,0.15) 0%, rgba(185,28,28,0.15) 100%);
# border: 1px solid rgba(239,68,68,0.4);
# padding: 16px 20px;
# border-radius: 10px;
# margin-top: 16px;
# box-shadow: 0 2px 8px rgba(239,68,68,0.15);">
# <p style="margin: 0; color: #fca5a5; font-weight: 600; font-size: 1.02em;">
# 🚫 Do NOT click "Run All" — run each cell one at a time to follow along with the exercises
# </p>
# </div>
# </div>

# %%
# Verify Python Environment
import sys

python_version = sys.version.split()[0]
required_version = "3.13"

print(f"🐍 Python Version: {python_version}")
print("─" * 50)

if python_version.startswith(required_version):
    print("✅ Environment Verified")
    print(f"   Running Python {python_version} (Required: {required_version}.x)")
    print("   Ready to proceed with workshop exercises.")
else:
    print(f"⚠️  Environment Mismatch Detected")
    print(f"   Current: Python {python_version}")
    print(f"   Required: Python {required_version}.x")
    print("\n📋 Action Required:")
    print("   1. Click the kernel selector (top-right corner)")
    print("   2. Select 'Python 3.13.3' from the dropdown")
    print("   3. Re-run this cell to verify")

# %% [markdown]
# ### About Strands SDK
# **Strands** is an open-source framework for building multi-agent AI systems with Amazon Bedrock. The `@tool` decorator makes Python functions discoverable to AI agents.
#
# 🔗 [Learn more at strandsagents.com](__https://strandsagents.com/__)
#
# ### Anatomy of a Strands Agent
# Every agent has 5 components:
# | Component | Example | Purpose |
# |-----------|---------|---------|
# | **1. Model** | `model_id="claude-sonnet-4"` | Which LLM powers reasoning |
# | **2. Tools** | `@tool def get_trending_products()` | Functions agent can call |
# | **3. System Prompt** | `"You are a product expert..."` | Agent's role and behavior |
# | **4. Memory** | `memory=MemoryStore()` | Retains context across conversations |
# | **5. Initialization** | `Agent(model_id, tools, instructions)` | Brings it all together |

# %% [markdown]
# ## Step 1: Import Required Libraries
#
# Let's import all the libraries we'll need for this section, including the Context Manager from the Blaize Bazaar backend.

# %% [markdown]
# <div style="background: linear-gradient(135deg, rgba(245,158,11,0.18) 0%, rgba(217,119,6,0.12) 100%);
#             backdrop-filter: blur(8px);
#             border: 1px solid rgba(245,158,11,0.3);
#             border-left: 5px solid #f59e0b;
#             padding: 16px 18px;
#             border-radius: 8px;
#             margin: 12px 0;
#             box-shadow: 0 3px 10px rgba(245,158,11,0.25);">
#     <strong style="color: #ffffff; font-size: 1.05em; display: block; margin-bottom: 6px;">
#         ⚠️ SETUP CELL
#     </strong>
#     <span style="color: #ffffff; font-size: 0.95em; line-height: 1.6; opacity: 0.95;">
#         Pre-written code that must be executed. No changes needed.
#     </span>
# </div>

# %%
# ============================================================================
# Import Required Libraries
# ============================================================================

# Core Python Libraries
import os
import json
from typing import List, Dict, Optional
from datetime import datetime
import time
import math

# Database & AWS Services
import psycopg
from psycopg.rows import dict_row
import boto3

# Interactive Widgets
import ipywidgets as widgets
from IPython.display import display, HTML, clear_output

# Strands SDK - Agent Framework
from strands import Agent, tool

# ============================================================================
# Imports Complete
# ============================================================================

display(HTML("""
    <div style="background: linear-gradient(135deg, rgba(40,167,69,0.18) 0%, rgba(34,139,34,0.12) 100%);
                backdrop-filter: blur(8px);
                border: 1px solid rgba(40,167,69,0.3);
                border-left: 5px solid #28a745;
                padding: 16px 20px;
                border-radius: 8px;
                margin: 16px 0;
                box-shadow: 0 3px 10px rgba(40,167,69,0.25);">
        <div style="color: #ffffff; font-size: 1.05em; font-weight: 600; margin-bottom: 8px;">
            ✅ Dependencies Loaded Successfully
        </div>
        <div style="color: #ffffff; font-size: 0.95em; font-weight: 400; opacity: 0.95; line-height: 1.6;">
            Core libraries, database connectors, and Strands SDK initialized for custom tool development.
        </div>
    </div>
"""))

# %% [markdown]
# ## Step 2: Environment Setup
#
# Configure the database connection and AWS Bedrock client.

# %% [markdown]
# <div style="background: linear-gradient(135deg, rgba(245,158,11,0.18) 0%, rgba(217,119,6,0.12) 100%);
#             backdrop-filter: blur(8px);
#             border: 1px solid rgba(245,158,11,0.3);
#             border-left: 5px solid #f59e0b;
#             padding: 16px 18px;
#             border-radius: 8px;
#             margin: 12px 0;
#             box-shadow: 0 3px 10px rgba(245,158,11,0.25);">
#     <strong style="color: #ffffff; font-size: 1.05em; display: block; margin-bottom: 6px;">
#         ⚠️ SETUP CELL
#     </strong>
#     <span style="color: #ffffff; font-size: 0.95em; line-height: 1.6; opacity: 0.95;">
#         Pre-written code that must be executed. No changes needed.
#     </span>
# </div>

# %%
# ============================================================================
# Environment Setup: Database Connection & Bedrock Client Initialization
# ============================================================================

import os
import json
import psycopg
from psycopg.rows import dict_row
import boto3
from typing import List, Dict, Optional
import time
from dotenv import load_dotenv

# Load environment configuration
load_dotenv('/workshop/sample-dat406-build-agentic-ai-powered-search-apg/.env')

# ============================================================================
# Database Configuration
# ============================================================================

DB_HOST = os.getenv('DB_HOST')
DB_PORT = os.getenv('DB_PORT', '5432')
DB_NAME = os.getenv('DB_NAME', 'postgres')
DB_USER = os.getenv('DB_USER')
DB_PASSWORD = os.getenv('DB_PASSWORD')

# Construct PostgreSQL connection string
conn_string = f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"

# ============================================================================
# Amazon Bedrock Client Initialization
# ============================================================================

bedrock = boto3.client(
    'bedrock-runtime', 
    region_name=os.environ.get('AWS_REGION', 'us-west-2')
)

# ============================================================================
# Verification
# ============================================================================

print("=" * 60)
print("✅ Environment Configuration Complete")
print("=" * 60)
print(f"📊 Aurora Endpoint: {conn_string.split('@')[1].split('/')[0]}")
print(f"🤖 Bedrock Region:  {bedrock.meta.region_name}")
print(f"🗄️ Database Name:   {DB_NAME}")
print("=" * 60)

# %% [markdown]
# ## Step 3: Helper Function for Demos
#
# This utility will help us demonstrate context management concepts throughout this notebook.

# %% [markdown]
# <div style="background: linear-gradient(135deg, rgba(40,167,69,0.18) 0%, rgba(34,139,34,0.12) 100%);
#             backdrop-filter: blur(8px);
#             border: 1px solid rgba(40,167,69,0.3);
#             border-left: 5px solid #28a745;
#             padding: 16px 18px;
#             border-radius: 8px;
#             margin: 12px 0;
#             box-shadow: 0 3px 10px rgba(40,167,69,0.25);">
#     <strong style="color: #ffffff; font-size: 1.05em; display: block; margin-bottom: 6px; font-weight: 600;">
#         ✅  CODE PROVIDED
#     </strong>
#     <span style="color: #ffffff; font-size: 0.95em; line-height: 1.6; font-weight: 400;">
#         Run this cell to initialize the generate_embedding() function.
#     </span>
# </div>

# %%
# ============================================================================
# Helper Functions for Generating Embeddings
# ============================================================================

def generate_embedding(text: str) -> str:
    """
    Generate embedding vector using Amazon Bedrock Titan Embeddings V2
    
    Args:
        text: Input text to embed
        
    Returns:
        String representation of 1024-dimensional embedding vector
    """
    try:
        response = bedrock.invoke_model(
            modelId='amazon.titan-embed-text-v2:0',
            body=json.dumps({"inputText": text})
        )
        response_body = json.loads(response['body'].read())
        return str(response_body.get('embedding'))
    except Exception as e:
        print(f"⚠️  Embedding generation error: {e}")
        return None


# Success confirmation
display(HTML("""
    <div style="background: linear-gradient(135deg, rgba(40,167,69,0.18) 0%, rgba(34,139,34,0.12) 100%);
                backdrop-filter: blur(8px);
                border: 1px solid rgba(40,167,69,0.3);
                border-left: 5px solid #28a745;
                padding: 12px 18px;
                border-radius: 8px;
                margin: 16px 0;
                box-shadow: 0 3px 10px rgba(40,167,69,0.25);">
        <span style="color: #ffffff; font-size: 1.02em; font-weight: 600;">
            ✅ Helper Function Loaded
        </span>
    </div>
"""))

# %% [markdown]
# ---
# # Section 0: MCP Foundation (5 minutes)
#
# ### Understanding the Infrastructure Layer

# %% [markdown]
# ### 0A. What is Model Context Protocol (MCP)?
#
# **MCP provides standardized access to data sources.** Think of it as three architectural layers:
#
# <img src="diagrams/part2_mcp_architecture.svg" alt="MCP Architecture - Three Layers" style="width: 100%; max-width: 950px; border-radius: 12px; margin: 20px 0;">
#
# ### Key Distinction
#
# | Layer | Knows... | Example |
# |-------|----------|----------|
# | **MCP Server** | **HOW** to access data | "Run this SQL query" |
# | **Custom Tools** | **WHAT** to do with data | "Trending = 4.5+ stars AND 50+ reviews" |
# | **Agents** | **WHEN** to use which tool | "Use trending tool for discovery, search tool for specific needs" |
#
# <div style="background: linear-gradient(135deg, rgba(88,28,135,0.18) 0%, rgba(124,58,237,0.12) 100%);
#             backdrop-filter: blur(8px);
#             border: 1px solid rgba(88,28,135,0.3);
#             border-left: 5px solid #7c3aed;
#             padding: 16px 18px;
#             border-radius: 8px;
#             margin: 12px 0;
#             box-shadow: 0 3px 10px rgba(88,28,135,0.25);">
#     <strong style="color: #ffffff; font-size: 1.05em; display: block; margin-bottom: 6px;">
#         💡 Why This Matters
#     </strong>
#     <span style="color: #ffffff; font-size: 0.95em; line-height: 1.6; opacity: 0.95;">
#         <strong>Schema discovery:</strong> MCP enables safe exploration of database structure without writing SQL<br>
#         <strong>Safe exploration:</strong> Read-only mode prevents accidental modifications during development<br>
#         <strong>Separation of concerns:</strong> MCP provides infrastructure, custom tools add business logic<br>
#         <strong>Reusability:</strong> The same PostgreSQL MCP works for any database application<br>
#         <strong>Domain-specific tools:</strong> Your e-commerce logic won't work for healthcare—custom tools encode your business rules<br>
#         <strong>Agent orchestration:</strong> Agents decide which tool to use based on context and user intent
#     </span>
# </div>

# %% [markdown]
# ### 0B. Your Aurora PostgreSQL MCP Server
#
# **Your workshop environment is pre-configured with an [Aurora PostgreSQL MCP Server](https://awslabs.github.io/mcp/servers/postgres-mcp-server)!**
#
# #### Configuration Location
# ```bash
# /workshop/sample-dat406-build-agentic-ai-powered-search-apg/blaize-bazaar/config/mcp-server-config.json
# ```
#
# #### MCP Server Configuration
# ```json
# {
#   "mcpServers": {
#     "awslabs.postgres-mcp-server": {
#       "command": "uvx",
#       "args": [
#         "awslabs.postgres-mcp-server@latest",
#         "--resource_arn", "${DB_CLUSTER_ARN}",
#         "--secret_arn", "${DB_SECRET_ARN}",
#         "--database", "${DB_NAME}",
#         "--region", "${AWS_REGION}",
#         "--readonly", "True"
#       ],
#       "env": {
#         "AWS_ACCESS_KEY_ID": "${AWS_ACCESS_KEY_ID}",
#         "AWS_SECRET_ACCESS_KEY": "${AWS_SECRET_ACCESS_KEY}",
#         "AWS_SESSION_TOKEN": "${AWS_SESSION_TOKEN}",
#         "AWS_REGION": "${AWS_REGION}",
#         "FASTMCP_LOG_LEVEL": "ERROR"
#       },
#       "disabled": false,
#       "autoApprove": []
#     }
#   }
# }
# ```
#
# **What this provides:**
# - ✅ Secure Aurora Data API access (no VPC required)
# - ✅ Schema introspection via `get_table_schema` tool
# - ✅ Generic SQL query execution via `run_query` tool
# - ✅ Automatic credential management from environment
#
# **Read-only mode:** Set to `True` for safety - prevents accidental data modifications during schema exploration.
#
# **Note:** `uvx` automatically installs and runs the latest version of the MCP server!

# %% [markdown]
# ### 0C. MCP vs Custom Tools in Practice
#
# #### Architecture Comparison
#
# | Layer | Purpose | When to Use | Example |
# |-------|---------|-------------|---------|
# | **MCP Server** | Schema exploration | Development & discovery | Amazon Q: "What tables exist?" |
# | **Direct Connection** | Production data access | Runtime operations | `psycopg.connect(conn_string)` |
# | **Custom Tools** | Business intelligence | Agent operations | `@tool get_trending_products()` |
# | **Agent** | Orchestration | User interactions | Decides which tool to call |
#
# #### Why We Use Different Approaches
#
# **MCP for Schema Exploration (What you just did):**
# - ✅ Safe read-only access
# - ✅ Perfect for Amazon Q assistance
# - ✅ Great for understanding database structure
# - ❌ Additional latency (not ideal for production queries)
#
# **Direct psycopg3 for Production (Parts 2 & 3):**
# - ✅ Lower latency (direct connection)
# - ✅ Better connection pooling
# - ✅ Production-optimized
# - ✅ Full control over queries
#
# #### Production Implementation Pattern
#
# **Direct database connection (not MCP):**
# ```python
# import psycopg
# from psycopg.rows import dict_row
#
# # Direct connection for production use
# conn_string = f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}/{DB_NAME}"
# ```
#
# **Your custom tool adds intelligence:**
# ```python
# @tool
# def get_trending_products(limit: int = 5) -> str:
#     """Trending = high ratings + proven popularity + in stock"""
#     with psycopg.connect(conn_string) as conn:  # ← Direct connection
#         with conn.cursor(row_factory=dict_row) as cur:
#             cur.execute("""
#                 SELECT * FROM product_catalog
#                 WHERE stars >= 4.5          -- ← Your business rule
#                   AND reviews > 50          -- ← Your business rule
#                   AND quantity > 0          -- ← Your business rule
#                 ORDER BY stars DESC, reviews DESC
#                 LIMIT %s
#             """, (limit,))
#             return format_as_json(cur.fetchall())  # ← Your formatting
# ```
#
# **Agent uses it intelligently (Part 3):**
# ```python
# if "trending" in user_query or "popular" in user_query:
#     result = get_trending_products()  # ← Agent's decision
# ```
#
# <div style="background: linear-gradient(135deg, rgba(88,28,135,0.18) 0%, rgba(124,58,237,0.12) 100%);
#             backdrop-filter: blur(8px);
#             border: 1px solid rgba(124,58,237,0.3);
#             border-left: 5px solid #7c3aed;
#             padding: 16px 18px;
#             border-radius: 8px;
#             margin: 12px 0;
#             box-shadow: 0 3px 10px rgba(88,28,135,0.25);">
#     <strong style="color: #ffffff; font-size: 1.05em; display: block; margin-bottom: 6px;">
#         🎯 Key Architectural Decision
#     </strong>
#     <span style="color: #ffffff; font-size: 0.95em; line-height: 1.6; opacity: 0.95;">
#         <strong>MCP (Section 0):</strong> Schema exploration with Amazon Q - excellent for development<br>
#         <strong>Direct Connection (Parts 2-3):</strong> Production queries - optimized for latency<br>
#         <strong>Custom Tools (Part 2):</strong> Business logic layer on top of direct connections<br>
#         <strong>Agents (Part 3):</strong> Orchestration of custom tools
#     </span>
# </div>
#
# <div style="background: linear-gradient(135deg, rgba(40,167,69,0.18) 0%, rgba(34,139,34,0.12) 100%);
#             backdrop-filter: blur(8px);
#             border: 1px solid rgba(40,167,69,0.3);
#             border-left: 5px solid #28a745;
#             padding: 12px 18px;
#             border-radius: 8px;
#             margin: 16px 0;
#             box-shadow: 0 3px 10px rgba(40,167,69,0.25);">
#     <span style="color: #ffffff; font-size: 1.02em; font-weight: 600;">
#         ✅ MCP Foundation Complete
#     </span>
#     <br>
#     <span style="color: #ffffff; font-size: 0.95em; opacity: 0.95;">
#         You've explored the schema with MCP. Now let's build custom tools using direct connections for production performance!
#     </span>
# </div>

# %% [markdown]
# ---
#
# # Section 1: Understanding Context Management

# %% [markdown]
# ## 1A. Token Counting: Accurate vs Estimation
#
# **Why this matters:** LLM costs are based on tokens, not characters. Inaccurate counting = budget surprises.
#
# **Critical for multi-agent systems:** Without strict token boundaries, costs spiral out of control:
#
# <div style="background: linear-gradient(135deg, rgba(239,68,68,0.15) 0%, rgba(220,38,38,0.12) 100%);
#             backdrop-filter: blur(8px);
#             border: 1px solid rgba(239,68,68,0.3);
#             border-left: 5px solid #ef4444;
#             padding: 16px 18px;
#             border-radius: 8px;
#             margin: 12px 0;
#             box-shadow: 0 3px 10px rgba(239,68,68,0.25);">
#     <strong style="color: #ffffff; font-size: 1.05em; display: block; margin-bottom: 6px;">
#         ⚠️ The Multi-Agent Token Problem
#     </strong>
#     <span style="color: #ffffff; font-size: 0.95em; line-height: 1.6; opacity: 0.95;">
#         <strong>Cascading tool calls:</strong> Orchestrator → Pricing Agent → Database Tool → 3 queries = 4x context overhead<br>
#         <strong>Context blow-up:</strong> Each agent adds conversation history + tool results to context window<br>
#         <strong>Example:</strong> User asks "best deals in electronics"<br>
#         &nbsp;&nbsp;• Orchestrator: 2K tokens (routing decision)<br>
#         &nbsp;&nbsp;• Pricing Agent: 5K tokens (analysis logic + previous context)<br>
#         &nbsp;&nbsp;• Tool results: 8K tokens (product data)<br>
#         &nbsp;&nbsp;• <strong>Total: 15K tokens for one query</strong> vs 2K with proper context management<br>
#         <strong>Without boundaries:</strong> 10 queries = 150K tokens = $0.45 vs $0.06 with optimization
#     </span>
# </div>
#
# **The solution:** Accurate token counting with `tiktoken` + intelligent pruning = predictable costs at scale.
#
# **The problem:** Estimating tokens by dividing character count by 4 gives 15-25% error.
#
# **The solution:** Use `tiktoken` - the same tokenizer Claude uses for 100% accurate counts.
#
# ### Quick Comparison
#
# | Method | Accuracy | Use Case | Example |
# |--------|----------|----------|---------|
# | **Character estimation** | ±20% error | Quick ballpark only | "Hello world" = 11 chars ÷ 4 = ~3 tokens |
# | **tiktoken** | 100% accurate | Production cost tracking | "Hello world" = 2 tokens (actual) |
#
# **At scale:** 20% error on 100K tokens = miscalculating by 20K tokens = real money.
#
# **Example:**
# ```python
# import tiktoken
#
# text = "Hello, how are you today?"
# encoding = tiktoken.encoding_for_model("claude-sonnet-4")
#
# # Character estimation
# char_estimate = len(text) / 4  # ~7 tokens
#
# # Actual count
# actual_tokens = len(encoding.encode(text))  # 6 tokens
#
# print(f"Estimate: {char_estimate:.0f} | Actual: {actual_tokens} | Error: {abs(char_estimate - actual_tokens)/actual_tokens:.1%}")
# ```
#
# **Output:** `Estimate: 7 | Actual: 6 | Error: 16.7%`

# %% [markdown]
# <div style="background: linear-gradient(135deg, rgba(40,167,69,0.18) 0%, rgba(34,139,34,0.12) 100%);
#             backdrop-filter: blur(8px);
#             border: 1px solid rgba(40,167,69,0.3);
#             border-left: 5px solid #28a745;
#             padding: 16px 18px;
#             border-radius: 8px;
#             margin: 12px 0;
#             box-shadow: 0 3px 10px rgba(40,167,69,0.25);">
#     <strong style="color: #ffffff; font-size: 1.05em; display: block; margin-bottom: 6px;">
#         ✅ CODE PROVIDED
#     </strong>
#     <span style="color: #ffffff; font-size: 0.95em; line-height: 1.6; opacity: 0.95;">
#         Installs tiktoken library and demonstrates accurate token counting vs estimation. Essential for context management.
#     </span>
# </div>

# %%
# ============================================================================
# Setup: tiktoken Installation & Encoder Initialization
# ============================================================================

import subprocess
import sys

# Install tiktoken if not present
try:
    import tiktoken
except ImportError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "tiktoken"])
    import tiktoken

# Initialize encoder (Claude Sonnet 4 uses cl100k_base)
encoder = tiktoken.get_encoding("cl100k_base")

# Token counting functions
def count_tokens_accurate(text: str) -> int:
    """Accurate count using tiktoken (100% accuracy)"""
    return len(encoder.encode(text))

def count_tokens_estimate(text: str) -> int:
    """Rough estimation: ~4 chars per token (15-25% error)"""
    return len(text) // 4

# ============================================================================
# Demonstration: tiktoken vs Estimation Comparison
# ============================================================================

test_texts = {
    "Short query": "wireless headphones",
    "Product desc": "Sony WH-1000XM5 Wireless Noise Canceling Headphones with 30-hour battery life",
    "SQL query": "SELECT * FROM bedrock_integration.product_catalog WHERE price < 100 ORDER BY rating DESC",
    "JSON data": '{"products": [{"id": "B07Q", "name": "Headphones", "price": 89.99, "rating": 4.5}]}'
}

# Build comparison table
rows = []
for text_type, text in test_texts.items():
    accurate = count_tokens_accurate(text)
    estimate = count_tokens_estimate(text)
    error = abs(accurate - estimate) / accurate * 100
    rows.append({
        'type': text_type,
        'chars': len(text),
        'accurate': accurate,
        'estimate': estimate,
        'error': error
    })

# Display results with professional styling
display(HTML(f"""
    <div style="background: linear-gradient(135deg, rgba(88,28,135,0.12) 0%, rgba(124,58,237,0.12) 100%);
                backdrop-filter: blur(8px);
                border: 1px solid rgba(88,28,135,0.3);
                padding: 20px;
                border-radius: 8px;
                margin: 16px 0;
                box-shadow: 0 3px 10px rgba(88,28,135,0.25);
                font-family: 'Courier New', monospace;">
        <div style="color: #ffffff; font-size: 1.15em; font-weight: 700; margin-bottom: 16px;">
            📊 Token Counting: tiktoken vs Estimation
        </div>
        <table style="width: 100%; border-collapse: collapse; color: #ffffff; font-size: 0.95em;">
            <thead>
                <tr style="border-bottom: 2px solid rgba(255,255,255,0.3);">
                    <th style="text-align: left; padding: 10px;">Text Type</th>
                    <th style="text-align: right; padding: 10px;">Chars</th>
                    <th style="text-align: right; padding: 10px;">tiktoken</th>
                    <th style="text-align: right; padding: 10px;">Estimate</th>
                    <th style="text-align: right; padding: 10px;">Error %</th>
                </tr>
            </thead>
            <tbody>
                {"".join([f'''
                <tr style="border-bottom: 1px solid rgba(255,255,255,0.1);">
                    <td style="padding: 10px; color: #c4b5fd;">{row['type']}</td>
                    <td style="text-align: right; padding: 10px;">{row['chars']}</td>
                    <td style="text-align: right; padding: 10px; color: #51cf66; font-weight: 600;">{row['accurate']}</td>
                    <td style="text-align: right; padding: 10px; color: #ffa94d;">{row['estimate']}</td>
                    <td style="text-align: right; padding: 10px; color: {'#f59e0b' if row['error'] > 20 else '#51cf66'};">
                        {row['error']:.1f}%
                    </td>
                </tr>
                ''' for row in rows])}
            </tbody>
        </table>
        <div style="background: rgba(255,255,255,0.1);
                    padding: 16px;
                    border-radius: 6px;
                    margin-top: 16px;
                    border-left: 4px solid #c4b5fd;">
            <div style="color: #c4b5fd; font-weight: 700; margin-bottom: 8px;">💡 Key Insights</div>
            <ul style="margin: 0; padding-left: 20px; line-height: 1.8; font-size: 0.95em;">
                <li><strong style="color: #51cf66;">tiktoken:</strong> 100% accurate (same tokenizer as Claude)</li>
                <li><strong style="color: #f59e0b;">Estimation:</strong> Can be 0-43% off (average ~26%)</li>
                <li><strong style="color: #c4b5fd;">Production:</strong> Always use tiktoken</li>
                <li><strong style="color: #9ca3af;">Development:</strong> Estimation OK for quick checks</li>
            </ul>
        </div>
    </div>
"""))

display(HTML("""
    <div style="background: linear-gradient(135deg, rgba(40,167,69,0.18) 0%, rgba(34,139,34,0.12) 100%);
                backdrop-filter: blur(8px);
                border: 1px solid rgba(40,167,69,0.3);
                border-left: 5px solid #28a745;
                padding: 12px 18px;
                border-radius: 8px;
                margin: 16px 0;
                box-shadow: 0 3px 10px rgba(40,167,69,0.25);">
        <span style="color: #ffffff; font-size: 1.02em; font-weight: 600;">
            ✅ tiktoken Loaded - Token Counting Ready
        </span>
    </div>
"""))

# %% [markdown]
# ## 1B. The Context Pyramid: 96% Token Reduction
#
# **The challenge:** Raw database access = 50K+ tokens per query. Too expensive for production.
#
# **The solution:** Progressive refinement through 4 layers.
#
# <img src="diagrams/part2_context_pyramid.svg" alt="Context Pyramid - 96% Token Reduction" style="width: 100%; max-width: 950px; border-radius: 12px; margin: 20px 0;">
#
# **Each layer optimizes for the layer above:**
# - **Raw Data:** Complete but overwhelming (50K+ tokens)
# - **Structured Tools:** Filtered and relevant (1-2K tokens) ← **96% reduction**
# - **Context Manager:** Tracks budget, auto-prunes
# - **Agent:** Makes decisions with clean context
#
# ### Token Efficiency: Before vs After
#
# | Scenario | Tokens | Cost/Query | Details |
# |----------|--------|------------|---------|
# | **❌ Without Context Management** | ~60,000 | $0.18 | Full schema + all data + complete history |
# | **✅ With Context Management** | ~4,000 | $0.012 | Structured tools + relevant context only |
# | **Savings** | **56K tokens** | **15x cheaper** | **96% reduction** |
#
# **Example: "What's trending?"**
# - **Without tools:** Send entire 21,704-product catalog = 50K+ tokens
# - **With `get_trending_products()`:** Return 10 filtered products = 1.5K tokens
# - **Reduction:** 97%

# %% [markdown]
# ---
#
# # Section 2: Building Custom Agent Tools

# %% [markdown]
# ## 2A. Why Custom Tools Over Generic MCP?
#
# **In Section 0, you explored the Aurora PostgreSQL MCP server** with its `run_query` and `get_table_schema` tools—excellent for schema exploration and ad-hoc queries.
#
# **For Blaize Bazaar's production system, we build custom tools on top of MCP.** Here's why:
#
# <div style="background: linear-gradient(135deg, rgba(88,28,135,0.25) 0%, rgba(124,58,237,0.20) 100%);
#             backdrop-filter: blur(8px);
#             border: 1px solid rgba(124,58,237,0.4);
#             padding: 20px;
#             border-radius: 10px;
#             margin: 20px 0;
#             box-shadow: 0 3px 12px rgba(88,28,135,0.3);">
#
# <div style="color: #ffffff;">
#
# | Aspect | Generic MCP (`run_query`) | Custom Tools (`@tool`) |
# |--------|---------------------------|------------------------|
# | **Security** | Full database access | Only specific operations with validation |
# | **Business Logic** | Agent writes SQL (variations) | Consistent rules (e.g., "trending" = 4.5+ stars, 50+ reviews) |
# | **Error Messages** | "Column 'xyz' not found" | "Try adjusting your search criteria" |
# | **Token Usage** | Returns all columns/rows | Returns only relevant, filtered data |
# | **Use Case** | Exploration & development | Production & end users |
#
# </div>
#
# </div>
#
# ### Blaize Bazaar's Custom Tool Pattern
#
# **MCP provides the connection, custom tools add intelligence:**
# ```python
# @tool
# def get_trending_products(limit: int = 10):
#     """Returns trending products with high ratings (4.5+) and many reviews (50+)"""
#     # Uses MCP connection, adds business rules
#
# @tool
# def semantic_product_search(query: str, max_price: Optional[float] = None):
#     """Combines semantic search from Part 1 with business filters"""
#     # Uses MCP connection + pgvector, adds filtering logic
#
# @tool
# def get_category_price_analysis(category: Optional[str] = None):
#     """Returns price statistics to help the pricing agent"""
#     # Uses MCP connection, adds aggregation & formatting
# ```

# %% [markdown]
# ## 2B. Custom Tool Pattern: Complete Example
#
# **Let's see how to build a production-ready custom tool with Strands SDK.**
#
# **Example:** `get_category_price_analysis()` - Pricing analysis for the Pricing Agent
#
# ### The @tool Decorator Pattern
# ```python
# from strands import tool
#
# @tool
# def get_category_price_analysis(category: str) -> str:
#     """Analyze pricing statistics for a product category."""
#     # Strands automatically:
#     # 1. Generates JSON schema from signature + docstring
#     # 2. Makes tool discoverable to Claude
#     # 3. Validates inputs and handles errors
# ```
#
# **How it works:**
# - **Type hints** (`str`) → Claude knows what to send
# - **Docstring** → Claude knows when to use it
# - **Return type** (`str` = JSON) → Claude knows what to expect
#
# Here's the complete implementation:

# %% [markdown]
# <div style="background: linear-gradient(135deg, rgba(40,167,69,0.18) 0%, rgba(34,139,34,0.12) 100%);
#             backdrop-filter: blur(8px);
#             border: 1px solid rgba(40,167,69,0.3);
#             border-left: 5px solid #28a745;
#             padding: 16px 18px;
#             border-radius: 8px;
#             margin: 12px 0;
#             box-shadow: 0 3px 10px rgba(40,167,69,0.25);">
#     <strong style="color: #ffffff; font-size: 1.05em; display: block; margin-bottom: 6px;">
#         ✅ CODE PROVIDED
#     </strong>
#     <span style="color: #ffffff; font-size: 0.95em; line-height: 1.6; opacity: 0.95;">
#         Run this cell to test your implementation.
#     </span>
# </div>

# %%
from strands import tool
import psycopg
from psycopg.rows import dict_row
import json

# ============================================================================
# Example: get_category_price_analysis() - Complete Implementation
# ============================================================================

@tool
def get_category_price_analysis(category: str) -> str:
    """
    Analyze pricing statistics for a product category.
    Provides min, max, average prices and product count.
    
    Args:
        category: Product category (e.g., "Electronics", "Home & Kitchen")
    
    Returns:
        JSON string with category pricing analysis
    """
    try:
        with psycopg.connect(conn_string) as conn:
            with conn.cursor(row_factory=dict_row) as cur:
                # Aggregation query with case-insensitive category matching
                cur.execute("""
                    SELECT 
                        category_name,
                        COUNT(*) as total_products,
                        MIN(price) as min_price,
                        MAX(price) as max_price,
                        AVG(price) as avg_price,
                        AVG(stars) as avg_rating
                    FROM bedrock_integration.product_catalog
                    WHERE category_name ILIKE %s 
                      AND quantity > 0
                    GROUP BY category_name
                """, (f"%{category}%",))
                
                row = cur.fetchone()
                
                if not row:
                    return json.dumps({"error": f"No products found in category: {category}"})
                
                # Structure the response
                result = {
                    "category": row["category_name"],
                    "analysis": {
                        "total_products": row["total_products"],
                        "price_range": {
                            "min": float(row["min_price"]),
                            "max": float(row["max_price"]),
                            "average": round(float(row["avg_price"]), 2)
                        },
                        "average_rating": round(float(row["avg_rating"]), 2)
                    }
                }
                
                return json.dumps(result, indent=2)
                
    except Exception as e:
        return json.dumps({"error": f"Analysis error: {str(e)}"})

print("✅ Tool defined: get_category_price_analysis()")

# %% [markdown]
# ### Test the Tool
#
# **Verify it works before building your own:**

# %%
# Test the tool
result = get_category_price_analysis("Electronics")
data = json.loads(result)

print("📊 Category Price Analysis:")
print("-" * 60)
print(f"Category: {data['category']}")
print(f"Total Products: {data['analysis']['total_products']:,}")
print(f"Price Range: ${data['analysis']['price_range']['min']:.2f} - ${data['analysis']['price_range']['max']:.2f}")
print(f"Average Price: ${data['analysis']['price_range']['average']:.2f}")
print(f"Average Rating: {data['analysis']['average_rating']}⭐")

# Token efficiency
token_estimate = len(result) // 4
print(f"\n💡 Token Efficiency:")
print(f"   Tool output: ~{token_estimate:,} tokens")
print(f"   Raw database dump: 50,000+ tokens")
print(f"   Reduction: ~{100 - (token_estimate/50000*100):.0f}%")

print("\n✅ This tool powers the Pricing Agent in Part 3!")

# %% [markdown]
# ## 2C. TODO Exercise: Build get_trending_products()
#
# **Your turn!** Build Blaize Bazaar's flagship product discovery tool.
#
# **Business rule:** "Trending" = high customer engagement
# - **High ratings:** 4.5+ stars
# - **Proven popularity:** 50+ reviews
# - **Available:** In stock only
# - **Sort:** By stars DESC, then reviews DESC
#
# **Requirements:**
# - Accept `limit` (int, default=5)
# - Filter with THREE conditions in WHERE clause
# - Sort by stars first, then review count
# - Return structured JSON with products + metadata
#
# **Expected output:**
# ```json
# {
#   "trending_products": [
#     {"id": "...", "name": "...", "price": 99.99, "rating": 4.8, "reviews": 1234}
#   ],
#   "count": 5,
#   "criteria": "stars >= 4.5, reviews > 50, in stock"
# }
# ```
#
# 💡 **Hints in the code cell below** - look for TODO comments!
#
# <div style="background: linear-gradient(135deg, rgba(88,28,135,0.18) 0%, rgba(124,58,237,0.12) 100%);
#             backdrop-filter: blur(8px);
#             border: 1px solid rgba(124,58,237,0.3);
#             border-left: 5px solid #7c3aed;
#             padding: 16px 18px;
#             border-radius: 8px;
#             margin: 12px 0;
#             box-shadow: 0 3px 10px rgba(88,28,135,0.25);">
#     <strong style="color: #ffffff; font-size: 1.05em; display: block; margin-bottom: 6px;">
#         📝 TODO - YOUR CODE HERE
#     </strong>
#     <span style="color: #ffffff; font-size: 0.95em; line-height: 1.6; opacity: 0.95;">
#         Complete the marked sections in this cell.
#     </span>
# </div>

# %%
# ============================================================================
# TODO: Implement get_trending_products()
# ============================================================================
# GUIDANCE:
# 1. Don't forget the decorator that makes this function discoverable to agents
# 2. Think about what makes a product "trending" - high ratings AND social proof
# 3. Only show products that are actually available to purchase
# 4. Return structured JSON that an agent can easily parse and present
# ============================================================================

def get_trending_products(limit: int = 5) -> str:
    """
    Get trending products based on ratings and reviews.
    Returns products with high ratings (4.5+) and many reviews (50+).
    
    Args:
        limit: Maximum number of products to return (default: 5)
    
    Returns:
        JSON string with trending products
    """
    try:
        # TODO: Connect to database using dict_row factory
        with psycopg.connect(conn_string) as conn:
            with conn.cursor(row_factory=dict_row) as cur:
                
                # TODO: Write your SELECT query
                # Think about:
                # - What product fields would be useful for display?
                # - How do you define "trending"? Consider ratings threshold and review count
                # - Should you include out-of-stock items?
                # - How should results be sorted to show the best first?
                
                cur.execute("""
                    SELECT 
                        -- TODO: Add columns for product display
                    FROM bedrock_integration.product_catalog
                    WHERE -- TODO: Add conditions for trending products
                    ORDER BY -- TODO: How to rank trending products?
                    LIMIT %s
                """, (limit,))
                
                products = cur.fetchall()
                
                # TODO: Format results as JSON for the agent
                # Structure should include: list of products, total count, 
                # and what criteria you used to define "trending"
                
                result = {
                    # TODO: Build your response structure
                }
                
                return json.dumps(result, indent=2)
                
    except Exception as e:
        return json.dumps({"error": f"Database error: {str(e)}"})

print("✅ Function defined - ready to test!")

# %% [markdown]
# ### 🧪 Test Your Implementation
#
# Run the cell below to verify your `get_trending_products()` function works correctly.

# %%
# ============================================================================
# Verification: Test Your Implementation
# ============================================================================

print("🧪 Testing get_trending_products()...\n")

try:
    result = get_trending_products(limit=3)
    data = json.loads(result)
    
    if "trending_products" in data and len(data["trending_products"]) > 0:
        print("✅ Tool working correctly!\n")
        print("🔥 Trending Products:")
        print("-" * 60)
        
        for i, product in enumerate(data["trending_products"], 1):
            print(f"{i}. {product['title'][:50]}")
            print(f"   ${product['price']:.2f} | {product['stars']}⭐ | {product['reviews']:,} reviews\n")
        
        print(f"Criteria: {data['criteria']}")
        print(f"Results: {data['count']} products")
        
        # Verify business logic
        all_high_rated = all(p['stars'] >= 4.5 for p in data["trending_products"])
        all_popular = all(p['reviews'] > 50 for p in data["trending_products"])
        
        if all_high_rated and all_popular:
            print("\n✅ Business logic verified!")
        else:
            print("\n⚠️  Check WHERE clause - some products don't meet criteria")
            
    else:
        print("❌ No results. Check your implementation.")
        print("\n💡 Common issues:")
        print("   - Missing WHERE clause conditions?")
        print("   - Check column names: \"productId\", \"imgUrl\" need quotes")
        print("   - Verify table name: bedrock_integration.product_catalog")
        
except Exception as e:
    print(f"❌ Error: {type(e).__name__}: {e}")
    print("\n📖 Stuck? Check Part_2_Solutions.ipynb")

# %% [markdown]
# ## 2D. Complete Blaize Bazaar Tool Suite
#
# **You built get_trending_products()!** ✅
#
# **Blaize Bazaar uses 6 custom tools total.** Here are the remaining 5 that power the multi-agent system in Part 3:

# %% [markdown]
# <div style="background: linear-gradient(135deg, rgba(40,167,69,0.18) 0%, rgba(34,139,34,0.12) 100%);
#             backdrop-filter: blur(8px);
#             border: 1px solid rgba(40,167,69,0.3);
#             border-left: 5px solid #28a745;
#             padding: 16px 18px;
#             border-radius: 8px;
#             margin: 12px 0;
#             box-shadow: 0 3px 10px rgba(40,167,69,0.25);">
#     <strong style="color: #ffffff; font-size: 1.05em; display: block; margin-bottom: 6px; font-weight: 600;">
#         ✅  CODE PROVIDED
#     </strong>
#     <span style="color: #ffffff; font-size: 0.95em; line-height: 1.6; font-weight: 400;">
#         Run this cell to initialize all the tools used in Blaize Bazaar.
#     </span>
# </div>

# %%
# ============================================================================
# Complete Blaize Bazaar Tool Suite
# ============================================================================
# These tools wrap the BusinessLogic class methods for agent use
# Note: get_trending_products() excluded - you already built that one!
# ============================================================================

from strands import tool
import psycopg
from psycopg.rows import dict_row
import json
from typing import List, Dict, Optional

# ============================================================================
# Tool 1: Inventory Health Monitoring
# ============================================================================

@tool
def get_inventory_health() -> str:
    """
    Retrieves current inventory health statistics.
    Used by Inventory Agent to monitor stock levels and identify critical items.
    
    Returns:
        JSON with inventory metrics, health score, and critical low-stock items
    """
    try:
        with psycopg.connect(conn_string) as conn:
            with conn.cursor(row_factory=dict_row) as cur:
                # Get inventory statistics
                cur.execute("""
                    SELECT 
                        COUNT(*) as total_products,
                        COUNT(CASE WHEN quantity = 0 THEN 1 END) as out_of_stock,
                        COUNT(CASE WHEN quantity > 0 AND quantity < 10 THEN 1 END) as low_stock,
                        COUNT(CASE WHEN quantity >= 10 THEN 1 END) as healthy_stock,
                        AVG(quantity) as avg_quantity,
                        SUM(quantity) as total_quantity
                    FROM bedrock_integration.product_catalog
                """)
                
                stats = dict(cur.fetchone())
                
                # Calculate health score (0-100)
                total = stats['total_products']
                healthy = stats['healthy_stock']
                health_score = int((healthy / total * 100)) if total > 0 else 0
                
                # Get critical items (low stock with high demand)
                cur.execute("""
                    SELECT 
                        "productId", product_description, stars, reviews, quantity
                    FROM bedrock_integration.product_catalog
                    WHERE quantity < 10 AND stars >= 4.0 AND reviews > 100
                    ORDER BY quantity ASC, reviews DESC
                    LIMIT 10
                """)
                
                critical_items = [dict(row) for row in cur.fetchall()]
                
                # Generate alerts
                alerts = []
                if stats['out_of_stock'] > 0:
                    alerts.append(f"🚨 {stats['out_of_stock']} products out of stock")
                if stats['low_stock'] > 100:
                    alerts.append(f"⚠️ {stats['low_stock']} products low stock (<10 units)")
                elif stats['low_stock'] > 0:
                    alerts.append(f"⚠️ {stats['low_stock']} products need monitoring")
                if not alerts:
                    alerts.append("✅ Inventory healthy")
                
                result = {
                    "health_score": health_score,
                    "statistics": {
                        "total_products": stats['total_products'],
                        "out_of_stock": stats['out_of_stock'],
                        "low_stock": stats['low_stock'],
                        "healthy_stock": stats['healthy_stock'],
                        "avg_quantity": round(float(stats['avg_quantity']), 2),
                        "total_quantity": int(stats['total_quantity'])
                    },
                    "critical_items": critical_items,
                    "alerts": alerts
                }
                
                return json.dumps(result, indent=2)
                
    except Exception as e:
        return json.dumps({"error": f"Inventory check error: {str(e)}"})


# ============================================================================
# Tool 2: Low Stock Products
# ============================================================================

@tool
def get_low_stock_products(limit: int = 3) -> str:
    """
    Get products with low stock (quantity < 10) prioritized by demand.
    Used by Inventory Agent to identify items needing restocking.
    
    Args:
        limit: Number of results (default: 3)
    
    Returns:
        JSON with low-stock products sorted by urgency (lowest quantity first)
    """
    try:
        with psycopg.connect(conn_string) as conn:
            with conn.cursor(row_factory=dict_row) as cur:
                cur.execute("""
                    SELECT 
                        "productId",
                        product_description,
                        price,
                        stars,
                        reviews,
                        category_name,
                        quantity,
                        "imgUrl",
                        "productURL"
                    FROM bedrock_integration.product_catalog
                    WHERE quantity < 10
                      AND stars >= 3.0
                    ORDER BY quantity ASC, reviews DESC, stars DESC
                    LIMIT %s
                """, (limit,))
                
                products = [dict(row) for row in cur.fetchall()]
                
                result = {
                    "status": "success",
                    "count": len(products),
                    "products": [{
                        "id": p["productId"],
                        "title": p["product_description"],
                        "category": p["category_name"],
                        "price": float(p["price"]),
                        "stars": float(p["stars"]),
                        "reviews": p["reviews"],
                        "quantity": p["quantity"],
                        "imgUrl": p.get("imgUrl", ""),
                        "productURL": p.get("productURL", "#")
                    } for p in products]
                }
                
                return json.dumps(result, indent=2)
                
    except Exception as e:
        return json.dumps({"error": f"Low stock check error: {str(e)}"})

# ============================================================================
# Tool 3: Category Price Analysis (shown earlier as example)
# ============================================================================

@tool
def get_category_price_analysis(category: str) -> str:
    """
    Analyze pricing statistics for a product category.
    Used by Pricing Agent for recommendations.
    
    Args:
        category: Product category (e.g., "Electronics", "Home & Kitchen")
    
    Returns:
        JSON with price statistics and best value products
    """
    try:
        with psycopg.connect(conn_string) as conn:
            with conn.cursor(row_factory=dict_row) as cur:
                # Get price statistics
                cur.execute("""
                    SELECT 
                        category_name, COUNT(*) as total_products,
                        MIN(price) as min_price, MAX(price) as max_price,
                        AVG(price) as avg_price, AVG(stars) as avg_rating
                    FROM bedrock_integration.product_catalog
                    WHERE category_name ILIKE %s AND quantity > 0
                    GROUP BY category_name
                """, (f"%{category}%",))
                
                row = cur.fetchone()
                
                if not row:
                    return json.dumps({"error": f"No products found in category: {category}"})
                
                # Get best value products (lowest price-to-rating ratio)
                cur.execute("""
                    SELECT "productId", product_description, price, stars, reviews,
                           "imgUrl", "productURL", (price / NULLIF(stars, 0)) as value_score
                    FROM bedrock_integration.product_catalog
                    WHERE category_name ILIKE %s AND quantity > 0 AND stars > 0 AND price > 0
                    ORDER BY value_score ASC LIMIT 5
                """, (f"%{category}%",))
                
                best_value = cur.fetchall()
                
                result = {
                    "category": row["category_name"],
                    "analysis": {
                        "total_products": row["total_products"],
                        "price_range": {
                            "min": float(row["min_price"]),
                            "max": float(row["max_price"]),
                            "average": round(float(row["avg_price"]), 2)
                        },
                        "average_rating": round(float(row["avg_rating"]), 2)
                    },
                    "best_value_products": [{
                        "id": p["productId"],
                        "title": p["product_description"],
                        "price": float(p["price"]),
                        "stars": float(p["stars"]),
                        "reviews": p["reviews"],
                        "imgUrl": p.get("imgUrl", ""),
                        "productURL": p.get("productURL", "#"),
                        "value_score": round(float(p["value_score"]), 2)
                    } for p in best_value]
                }
                
                return json.dumps(result, indent=2)
                
    except Exception as e:
        return json.dumps({"error": f"Analysis error: {str(e)}"})


# ============================================================================
# Tool 4: Product Restocking
# ============================================================================

@tool
def restock_product(product_id: str, quantity: int) -> str:
    """
    Restock a product by updating its quantity.
    Used by Inventory Agent for stock management.
    
    Args:
        product_id: Product ID to restock
        quantity: Amount to add to inventory
    
    Returns:
        JSON with restock confirmation and updated quantities
    """
    try:
        with psycopg.connect(conn_string) as conn:
            with conn.cursor(row_factory=dict_row) as cur:
                # Get current product info
                cur.execute("""
                    SELECT "productId", product_description, quantity
                    FROM bedrock_integration.product_catalog
                    WHERE "productId" = %s
                """, (product_id,))
                
                product = cur.fetchone()
                
                if not product:
                    return json.dumps({
                        "status": "error",
                        "message": f"Product {product_id} not found"
                    })
                
                old_quantity = product['quantity']
                new_quantity = old_quantity + quantity
                
                # Update quantity
                cur.execute("""
                    UPDATE bedrock_integration.product_catalog
                    SET quantity = quantity + %s
                    WHERE "productId" = %s
                """, (quantity, product_id))
                
                conn.commit()
                
                result = {
                    "status": "success",
                    "product_id": product_id,
                    "product_name": product['product_description'],
                    "old_quantity": old_quantity,
                    "added_quantity": quantity,
                    "new_quantity": new_quantity,
                    "message": f"✅ Added {quantity} units to {product['product_description']}"
                }
                
                return json.dumps(result, indent=2)
                
    except Exception as e:
        return json.dumps({"error": f"Restock error: {str(e)}"})


# ============================================================================
# Tool 5: Semantic Product Search
# ============================================================================

@tool
def semantic_product_search(query: str, max_price: float = None,
                            min_rating: float = 4.0, category: str = None,
                            limit: int = 5) -> str:
    """
    AI-powered semantic search combining Part 1's pgvector with filters.
    
    Args:
        query: Natural language search query
        max_price: Optional maximum price filter
        min_rating: Minimum star rating (default: 4.0)
        category: Optional category filter
        limit: Max results (default: 5)
    
    Returns:
        JSON with matching products and similarity scores
    """
    try:
        # Generate embedding
        query_embedding = generate_embedding(query)
        if not query_embedding:
            return json.dumps({"error": "Failed to generate embedding"})
        
        # Build WHERE clause with filters
        conditions = ["quantity > 0"]
        params = []
        
        if max_price:
            conditions.append("price <= %s")
            params.append(max_price)
        
        if min_rating:
            conditions.append("stars >= %s")
            params.append(min_rating)
        
        if category:
            conditions.append("category_name ILIKE %s")
            params.append(f"%{category}%")
        
        where_clause = " AND ".join(conditions)
        # Add embedding params: 1 for SELECT similarity, 1 for ORDER BY, then limit
        params.insert(0, str(query_embedding))
        params.append(str(query_embedding))
        params.append(limit)
        
        with psycopg.connect(conn_string) as conn:
            with conn.cursor(row_factory=dict_row) as cur:
                cur.execute(f"""
                    SELECT 
                        "productId", product_description, price, stars, reviews,
                        category_name, quantity, "imgUrl", "productURL",
                        1 - (embedding <=> %s::vector) as similarity
                    FROM bedrock_integration.product_catalog
                    WHERE {where_clause}
                    ORDER BY embedding <=> %s::vector
                    LIMIT %s
                """, params)
                
                products = cur.fetchall()
                
                result = {
                    "query": query,
                    "matches": [{
                        "id": p["productId"],
                        "title": p["product_description"],
                        "category": p["category_name"],
                        "price": float(p["price"]),
                        "stars": float(p["stars"]),
                        "reviews": p["reviews"],
                        "imgUrl": p.get("imgUrl", ""),
                        "productURL": p.get("productURL", "#"),
                        "similarity": round(float(p["similarity"]), 3)
                    } for p in products],
                    "count": len(products),
                    "filters": {
                        "max_price": max_price,
                        "min_rating": min_rating,
                        "category": category
                    }
                }
                
                return json.dumps(result, indent=2)
                
    except Exception as e:
        return json.dumps({"error": f"Search error: {str(e)}"})


# ============================================================================
# Tool 6: Category-Based Product Retrieval
# ============================================================================

@tool
def get_product_by_category(category: str, min_rating: float = 4.0,
                            max_price: float = None, limit: int = 10) -> str:
    """
    Retrieve products by category with rating and price filters.
    
    Args:
        category: Product category (required)
        min_rating: Minimum star rating (default: 4.0)
        max_price: Optional maximum price
        limit: Max results (default: 10)
    
    Returns:
        JSON with filtered products sorted by rating and reviews
    """
    try:
        conditions = ["category_name ILIKE %s", "quantity > 0"]
        params = [f"%{category}%"]
        
        if min_rating:
            conditions.append("stars >= %s")
            params.append(min_rating)
        
        if max_price:
            conditions.append("price <= %s")
            params.append(max_price)
        
        where_clause = " AND ".join(conditions)
        params.append(limit)
        
        with psycopg.connect(conn_string) as conn:
            with conn.cursor(row_factory=dict_row) as cur:
                cur.execute(f"""
                    SELECT 
                        "productId", product_description, price, stars, reviews,
                        category_name, quantity, "imgUrl", "productURL"
                    FROM bedrock_integration.product_catalog
                    WHERE {where_clause}
                    ORDER BY stars DESC, reviews DESC
                    LIMIT %s
                """, params)
                
                products = cur.fetchall()
                
                result = {
                    "category": category,
                    "products": [{
                        "id": p["productId"],
                        "title": p["product_description"],
                        "category": p["category_name"],
                        "price": float(p["price"]),
                        "stars": float(p["stars"]),
                        "reviews": p["reviews"],
                        "quantity": p["quantity"],
                        "imgUrl": p.get("imgUrl", ""),
                        "productURL": p.get("productURL", "#")
                    } for p in products],
                    "count": len(products),
                    "filters": {
                        "min_rating": min_rating,
                        "max_price": max_price
                    }
                }
                
                return json.dumps(result, indent=2)
                
    except Exception as e:
        return json.dumps({"error": f"Category search error: {str(e)}"})


# ============================================================================
# Verify Tools Loaded
# ============================================================================

print("✅ All 7 Blaize Bazaar tools loaded!")
print("\n📦 Complete Tool Suite:")
print("   1. get_inventory_health() - Inventory monitoring & alerts")
print("   2. get_low_stock_products() - Find items needing restocking")
print("   3. get_category_price_analysis() - Pricing insights & best value")
print("   4. restock_product() - Inventory management operations")
print("   5. semantic_product_search() - Natural language search with pgvector")
print("   6. get_product_by_category() - Category filtering with ratings")
print("   7. get_trending_products() ← You built this!")
print("\n🚀 Ready for Part 3's multi-agent orchestration!")

# %% [markdown]
# ---
# ### Try the Tools Interactively
#
# **Test the discovery tools** with the interactive widget below:
#
# **Available in widget:**
# - `get_trending_products()` ← Your implementation!
# - `semantic_product_search()` - Natural language queries
# - `get_category_price_analysis()` - Pricing insights

# %% [markdown]
# <div style="background: linear-gradient(135deg, rgba(245,158,11,0.18) 0%, rgba(217,119,6,0.12) 100%);
#             backdrop-filter: blur(8px);
#             border: 1px solid rgba(245,158,11,0.3);
#             border-left: 5px solid #f59e0b;
#             padding: 16px 18px;
#             border-radius: 8px;
#             margin: 12px 0;
#             box-shadow: 0 3px 10px rgba(245,158,11,0.25);">
#     <strong style="color: #ffffff; font-size: 1.05em; display: block; margin-bottom: 6px;">
#         ⚠️ PRODUCT DISPLAY CARD - EXECUTE TO INITIALIZE
#     </strong>
#     <span style="color: #ffffff; font-size: 0.95em; line-height: 1.6; opacity: 0.95;">
#         Initialize the product card display helper.
#     </span>
# </div>

# %%
def display_product_cards(products: List[Dict], tool_name: str, extra_info: str = ""):
    """
    Display products as beautiful cards.
    Enhanced readability for product names and review counts.
    """
    html = f"""
    <div style="background: linear-gradient(135deg, #581c87 0%, #7c3aed 100%);
                backdrop-filter: blur(10px);
                border: 1px solid rgba(255,255,255,0.1);
                padding: 20px;
                border-radius: 10px;
                color: white;
                margin: 20px 0;
                box-shadow: 0 8px 20px rgba(88,28,135,0.4);">
        <h3 style="margin: 0; font-weight: 700; text-shadow: 0 2px 4px rgba(0,0,0,0.2);">🔧 {tool_name}</h3>
        {f'<p style="margin: 5px 0 0 0; font-size: 0.95em; opacity: 0.95;">{extra_info}</p>' if extra_info else ''}
    </div>
    """
    
    if not products:
        html += "<p style='padding: 20px; color: #9ca3af; text-align: center;'>❌ No results found</p>"
    else:
        for product in products:
            img_url = product.get('imgUrl', '')
            product_url = product.get('productURL', '#')
            
            html += f"""
            <div style="display: flex; gap: 20px; padding: 18px;
                        border: 2px solid rgba(255,255,255,0.1);
                        border-radius: 10px; margin-bottom: 15px;
                        background: rgba(255,255,255,0.03);">
                <img src="{img_url}" alt="{product.get('title', '')[:50]}" 
                     style="flex-shrink: 0; width: 120px; height: 120px; object-fit: contain; 
                            border-radius: 8px; background: white; padding: 10px;
                            border: 1px solid rgba(255,255,255,0.2);"
                     onerror="this.src='data:image/svg+xml,<svg xmlns=%22http://www.w3.org/2000/svg%22 width=%22120%22 height=%22120%22><rect width=%22120%22 height=%22120%22 fill=%22%23f0f0f0%22/><text x=%2250%%25%22 y=%2250%%25%22 text-anchor=%22middle%22 dy=%22.3em%22 fill=%22%23999%22 font-size=%2214%22>No Image</text></svg>'">
                <div style="flex: 1; display: flex; flex-direction: column; gap: 10px;">
                    <a href="{product_url}" target="_blank" 
                       style="font-size: 1.1em; font-weight: 600; color: #1a1a1a;
                              text-decoration: none; line-height: 1.5; letter-spacing: 0.01em;">
                        {product.get('title', 'Unknown Product')[:80]}...
                    </a>
                    <div style="display: flex; flex-wrap: wrap; gap: 15px; align-items: center;">
                        <span style="font-size: 1.35em; font-weight: 700; color: #ef4444; 
                                     text-shadow: 0 1px 2px rgba(0,0,0,0.2);">
                            💰 ${product.get('price', 0):.2f}
                        </span>
                        <span style="color: #fbbf24; font-size: 1em; font-weight: 600;">
                            ⭐ {product.get('stars', 0)}
                        </span>
                        <span style="color: #4b5563; font-size: 0.95em; font-weight: 500; 
                                     letter-spacing: 0.02em;">
                            ({product.get('reviews', 0):,} reviews)
                        </span>
            """
            
            # Add tool-specific metrics with purple gradient styling
            if 'similarity' in product:
                similarity_pct = product['similarity'] * 100
                html += f"""
                        <span style="background: linear-gradient(135deg, #581c87 0%, #7c3aed 100%); 
                                     color: white; padding: 6px 12px; border-radius: 20px; font-weight: 600;
                                     font-size: 0.9em; letter-spacing: 0.02em;
                                     box-shadow: 0 2px 4px rgba(88,28,135,0.3);">
                            🎯 {similarity_pct:.1f}% similar
                        </span>
                """
            elif 'value_score' in product:
                html += f"""
                        <span style="background: linear-gradient(135deg, #581c87 0%, #7c3aed 100%); 
                                     color: white; padding: 6px 12px; border-radius: 20px; font-weight: 600;
                                     font-size: 0.9em; letter-spacing: 0.02em;
                                     box-shadow: 0 2px 4px rgba(88,28,135,0.3);">
                            💎 ${product['value_score']:.2f}/star
                        </span>
                """
            
            html += """
                    </div>
                </div>
            </div>
            """
    
    display(HTML(html))

display(HTML("""
    <div style="background: linear-gradient(135deg, rgba(88,28,135,0.18) 0%, rgba(124,58,237,0.12) 100%);
                backdrop-filter: blur(8px);
                border: 1px solid rgba(88,28,135,0.3);
                border-left: 5px solid #7c3aed;
                padding: 12px 18px;
                border-radius: 8px;
                margin: 16px 0;
                box-shadow: 0 3px 10px rgba(88,28,135,0.25);">
        <span style="color: #ffffff; font-size: 1.02em; font-weight: 600;">
            ✅ Product Card Display Helper Ready
        </span>
    </div>
"""))

# %% [markdown]
# <div style="background: linear-gradient(135deg, rgba(245,158,11,0.18) 0%, rgba(217,119,6,0.12) 100%);
#             backdrop-filter: blur(8px);
#             border: 1px solid rgba(245,158,11,0.3);
#             border-left: 5px solid #f59e0b;
#             padding: 16px 18px;
#             border-radius: 8px;
#             margin: 12px 0;
#             box-shadow: 0 3px 10px rgba(245,158,11,0.25);">
#     <strong style="color: #ffffff; font-size: 1.05em; display: block; margin-bottom: 6px;">
#         ⚠️ INTERACTIVE WIDGET - EXECUTE TO DISPLAY
#     </strong>
#     <span style="color: #ffffff; font-size: 0.95em; line-height: 1.6; opacity: 0.95;">
#         Run this cell to launch the interactive product search comparison widget.
#     </span>
# </div>

# %%
# ==================================
# Interactive Tool Explorer Widget 
# ==================================

# Create interactive widget controls
tool_selector = widgets.Dropdown(
    options=['Trending Products', 'Semantic Search', 'Price Analysis'],
    description='Tool:',
    style={'description_width': '100px'}
)

search_query = widgets.Text(
    placeholder='e.g., laptop for programming',
    description='Search:',
    style={'description_width': '100px'}
)

max_price = widgets.FloatText(
    value=0,
    description='Max Price:',
    style={'description_width': '100px'}
)

min_rating = widgets.FloatSlider(
    value=0,
    min=0,
    max=5,
    step=0.5,
    description='Min Rating:',
    style={'description_width': '100px'}
)

category = widgets.Dropdown(
    options=['Health & Household', 'Smart Home: Security Cameras and Systems', 
             'Smart Home: WiFi and Networking', 'Smart Home: Smart Locks and Entry', 
             'RV Parts & Accessories', 'Learning & Education Toys'],
    value='Health & Household',
    description='Category:',
    style={'description_width': '100px'}
)

result_limit = widgets.IntSlider(
    value=5,
    min=1,
    max=10,
    description='Limit:',
    style={'description_width': '100px'}
)

test_button = widgets.Button(
    description='🔍 Test Tool',
    button_style='success',
    layout=widgets.Layout(width='150px', height='40px')
)

tool_output = widgets.Output()

def update_visibility(change):
    """Show/hide parameters based on selected tool."""
    tool = change['new']
    if tool == 'Trending Products':
        search_params.layout.display = 'none'
        price_params.layout.display = 'none'
        trending_params.layout.display = 'block'
    elif tool == 'Semantic Search':
        search_params.layout.display = 'block'
        price_params.layout.display = 'none'
        trending_params.layout.display = 'none'
    else:  # Price Analysis
        search_params.layout.display = 'none'
        price_params.layout.display = 'block'
        trending_params.layout.display = 'none'

def test_tool(b):
    """Execute the selected tool with provided parameters."""
    tool_output.clear_output()
    
    with tool_output:
        clear_output(wait=True)
        tool = tool_selector.value
        
        try:
            if tool == 'Trending Products':
                result_str = get_trending_products(limit=result_limit.value)
                result = json.loads(result_str)
                
                if 'error' not in result:
                    display_product_cards(
                        result['trending_products'], 
                        f"Top {result['count']} Trending Products",
                        "High ratings (4.5+) with proven popularity (50+ reviews)"
                    )
                else:
                    display(HTML(f"""
                    <div style="background: linear-gradient(135deg, rgba(239,68,68,0.18) 0%, rgba(220,38,38,0.12) 100%);
                                backdrop-filter: blur(8px);
                                border: 1px solid rgba(239,68,68,0.3);
                                border-left: 5px solid #ef4444;
                                padding: 16px 18px;
                                border-radius: 8px;
                                margin: 12px 0;
                                box-shadow: 0 3px 10px rgba(239,68,68,0.25);">
                        <div style="color: #ffffff; font-size: 1.02em; font-weight: 600; margin-bottom: 4px;">
                            ❌ Error
                        </div>
                        <div style="color: #ffffff; font-size: 0.95em; opacity: 0.95;">
                            {result['error']}
                        </div>
                    </div>
                    """))
                    
            elif tool == 'Semantic Search':
                if not search_query.value:
                    display(HTML("""
                    <div style="background: linear-gradient(135deg, rgba(239,68,68,0.18) 0%, rgba(220,38,38,0.12) 100%);
                                backdrop-filter: blur(8px);
                                border: 1px solid rgba(239,68,68,0.3);
                                border-left: 5px solid #ef4444;
                                padding: 16px 18px;
                                border-radius: 8px;
                                margin: 12px 0;
                                box-shadow: 0 3px 10px rgba(239,68,68,0.25);">
                        <div style="color: #ffffff; font-size: 1.02em; font-weight: 600; margin-bottom: 4px;">
                            ❌ Missing Input
                        </div>
                        <div style="color: #ffffff; font-size: 0.95em; opacity: 0.95;">
                            Please enter a search query
                        </div>
                    </div>
                    """))
                    return
                    
                start_time = time.time()
                result_str = semantic_product_search(query=search_query.value, max_price=max_price.value if max_price.value > 0 else None, min_rating=min_rating.value if min_rating.value > 0 else None, limit=result_limit.value)
                query_time_ms = int((time.time() - start_time) * 1000)
                result = json.loads(result_str)
                
                if 'error' not in result:
                    display_product_cards(
                        result.get('matches', result.get('trending_products', [])),
                        f"Semantic Search: \"{result['query']}\"",
                        f"Found {result['count']} products | ⚡ {query_time_ms}ms"
                    )
                else:
                    display(HTML(f"""
                    <div style="background: linear-gradient(135deg, rgba(239,68,68,0.18) 0%, rgba(220,38,38,0.12) 100%);
                                backdrop-filter: blur(8px);
                                border: 1px solid rgba(239,68,68,0.3);
                                border-left: 5px solid #ef4444;
                                padding: 16px 18px;
                                border-radius: 8px;
                                margin: 12px 0;
                                box-shadow: 0 3px 10px rgba(239,68,68,0.25);">
                        <div style="color: #ffffff; font-size: 1.02em; font-weight: 600; margin-bottom: 4px;">
                            ❌ Error
                        </div>
                        <div style="color: #ffffff; font-size: 0.95em; opacity: 0.95;">
                            {result['error']}
                        </div>
                    </div>
                    """))
                    
            else:  # Price Analysis
                if not category.value:
                    display(HTML("""
                    <div style="background: linear-gradient(135deg, rgba(239,68,68,0.18) 0%, rgba(220,38,38,0.12) 100%);
                                backdrop-filter: blur(8px);
                                border: 1px solid rgba(239,68,68,0.3);
                                border-left: 5px solid #ef4444;
                                padding: 16px 18px;
                                border-radius: 8px;
                                margin: 12px 0;
                                box-shadow: 0 3px 10px rgba(239,68,68,0.25);">
                        <div style="color: #ffffff; font-size: 1.02em; font-weight: 600; margin-bottom: 4px;">
                            ❌ Missing Input
                        </div>
                        <div style="color: #ffffff; font-size: 0.95em; opacity: 0.95;">
                            Please select a category
                        </div>
                    </div>
                    """))
                    return
                    
                result_str = get_category_price_analysis(category.value)
                result = json.loads(result_str)
                
                if 'error' not in result:
                    # Display price analysis with purple glassmorphism styling
                    display(HTML(f"""
                    <div style="background: linear-gradient(135deg, rgba(88,28,135,0.12) 0%, rgba(124,58,237,0.12) 100%);
                                backdrop-filter: blur(10px);
                                border: 2px solid rgba(88,28,135,0.25);
                                padding: 24px;
                                border-radius: 12px;
                                margin-bottom: 20px;
                                box-shadow: 0 4px 15px rgba(88,28,135,0.3), inset 0 1px 0 rgba(255,255,255,0.1);">
                        <h4 style="margin: 0 0 16px 0; color: #1a1a1a; font-size: 1.3em; font-weight: 700; 
                                    text-shadow: 0 1px 2px rgba(255,255,255,0.5);">
                            📊 Price Analysis: {result['category']}
                        </h4>
                        <div style="display: flex; gap: 30px; flex-wrap: wrap;">
                            <div style="background: rgba(88,28,135,0.15); 
                                        padding: 12px 16px; 
                                        border-radius: 8px; 
                                        border: 1px solid rgba(124,58,237,0.2);">
                                <div style="font-size: 0.85em; color: #581c87; margin-bottom: 4px; font-weight: 700;">
                                    Total Products
                                </div>
                                <div style="font-size: 1.4em; font-weight: 700; color: #1a1a1a;">
                                    {result['analysis']['total_products']}
                                </div>
                            </div>
                            <div style="background: rgba(88,28,135,0.15); 
                                        padding: 12px 16px; 
                                        border-radius: 8px; 
                                        border: 1px solid rgba(124,58,237,0.2);">
                                <div style="font-size: 0.85em; color: #581c87; margin-bottom: 4px; font-weight: 700;">
                                    Price Range
                                </div>
                                <div style="font-size: 1.4em; font-weight: 700; color: #1a1a1a;">
                                    ${result['analysis']['price_range']['min']:.2f} - ${result['analysis']['price_range']['max']:.2f}
                                </div>
                            </div>
                            <div style="background: rgba(88,28,135,0.15); 
                                        padding: 12px 16px; 
                                        border-radius: 8px; 
                                        border: 1px solid rgba(124,58,237,0.2);">
                                <div style="font-size: 0.85em; color: #581c87; margin-bottom: 4px; font-weight: 700;">
                                    Average Price
                                </div>
                                <div style="font-size: 1.4em; font-weight: 700; color: #1a1a1a;">
                                    ${result['analysis']['price_range']['average']:.2f}
                                </div>
                            </div>
                        </div>
                    </div>
                    """))
                    
                    display_product_cards(
                        result['best_value_products'],
                        "Top 5 Best Value Products",
                        "Ranked by price per star (lower is better value)"
                    )
                else:
                    display(HTML(f"""
                    <div style="background: linear-gradient(135deg, rgba(239,68,68,0.18) 0%, rgba(220,38,38,0.12) 100%);
                                backdrop-filter: blur(8px);
                                border: 1px solid rgba(239,68,68,0.3);
                                border-left: 5px solid #ef4444;
                                padding: 16px 18px;
                                border-radius: 8px;
                                margin: 12px 0;
                                box-shadow: 0 3px 10px rgba(239,68,68,0.25);">
                        <div style="color: #ffffff; font-size: 1.02em; font-weight: 600; margin-bottom: 4px;">
                            ❌ Error
                        </div>
                        <div style="color: #ffffff; font-size: 0.95em; opacity: 0.95;">
                            {result['error']}
                        </div>
                    </div>
                    """))
                    
        except Exception as e:
            display(HTML(f"""
            <div style="background: linear-gradient(135deg, rgba(239,68,68,0.18) 0%, rgba(220,38,38,0.12) 100%);
                        backdrop-filter: blur(8px);
                        border: 1px solid rgba(239,68,68,0.3);
                        border-left: 5px solid #ef4444;
                        padding: 16px 18px;
                        border-radius: 8px;
                        margin: 12px 0;
                        box-shadow: 0 3px 10px rgba(239,68,68,0.25);">
                <div style="color: #ffffff; font-size: 1.02em; font-weight: 600; margin-bottom: 4px;">
                    ❌ Unexpected Error
                </div>
                <div style="color: #ffffff; font-size: 0.95em; opacity: 0.95;">
                    {str(e)}
                </div>
            </div>
            """))

# Wire up the interface
tool_selector.observe(update_visibility, 'value')
test_button.on_click(test_tool)

# Group parameters by tool
search_params = widgets.VBox([search_query, max_price, min_rating, result_limit])
price_params = widgets.VBox([category])
trending_params = widgets.VBox([result_limit])

# Initial visibility
search_params.layout.display = 'none'
price_params.layout.display = 'none'

# Create the title header with deep purple glassmorphism
title_html = widgets.HTML("""
<div style="background: linear-gradient(135deg, #581c87 0%, #7c3aed 100%);
            backdrop-filter: blur(10px);
            border: 1px solid rgba(255,255,255,0.1);
            padding: 28px;
            border-radius: 12px;
            color: white;
            margin-bottom: 20px;
            box-shadow: 0 10px 30px rgba(88,28,135,0.4), 0 1px 8px rgba(88,28,135,0.2);">
    <h2 style="margin: 0 0 12px 0; font-size: 1.8em; font-weight: 700; 
                text-shadow: 0 2px 4px rgba(0,0,0,0.2);">
        🎮 Interactive Tool Explorer
    </h2>
    <p style="margin: 0; font-size: 1.1em; line-height: 1.7; opacity: 0.95;">
        Test your three custom tools with beautiful product cards
    </p>
</div>
<div style="background: linear-gradient(135deg, rgba(88,28,135,0.12) 0%, rgba(124,58,237,0.12) 100%);
            backdrop-filter: blur(8px);
            border: 1px solid rgba(88,28,135,0.25);
            border-left: 4px solid #7c3aed;
            padding: 18px;
            margin-bottom: 20px;
            border-radius: 10px;
            box-shadow: 0 3px 12px rgba(88,28,135,0.2), inset 0 1px 0 rgba(255,255,255,0.05);">
    <p style="margin: 0 0 12px 0; color: #1a1a1a; font-weight: 600; font-size: 1.1em;">
        💡 How to Use:
    </p>
    <ul style="margin: 0; padding-left: 20px; color: #1a1a1a; line-height: 1.8;">
        <li>Select a tool from the dropdown to test different capabilities</li>
        <li>Adjust parameters to see how filtering and limits work</li>
        <li>Notice how each tool returns data formatted for its specific purpose</li>
        <li>Product cards show images, prices, ratings, and tool-specific metrics</li>
    </ul>
</div>
""")

# Display the widget
display(widgets.VBox([
    title_html,
    tool_selector,
    search_params,
    price_params,
    trending_params,
    test_button,
    tool_output
], layout=widgets.Layout(padding='20px')))

# Success message with purple glassmorphism
display(HTML("""
    <div style="background: linear-gradient(135deg, rgba(88,28,135,0.18) 0%, rgba(124,58,237,0.12) 100%);
                backdrop-filter: blur(8px);
                border: 1px solid rgba(88,28,135,0.3);
                border-left: 5px solid #7c3aed;
                padding: 12px 18px;
                border-radius: 8px;
                margin: 16px 0;
                box-shadow: 0 3px 10px rgba(88,28,135,0.25);">
        <div style="color: #ffffff; font-size: 1.02em; font-weight: 600; margin-bottom: 4px;">
            ✅ Interactive Widget Ready
        </div>
        <div style="color: #ffffff; font-size: 0.95em; opacity: 0.95;">
            🎯 Try different tools and parameters to see how agents use these capabilities
        </div>
    </div>
"""))

# %% [markdown]
# ---
#
# # Integration & Next Steps
#
# ## What You Built in Part 2
#
# ✅ **Token optimization** - 96% reduction (50K → 2K tokens)
# ✅ **Custom tool pattern** - `@tool` decorator + business logic
# ✅ **get_trending_products()** - Production-ready implementation
# ✅ **Complete tool suite** - 6 tools ready for multi-agent orchestration
#
# **How Parts 1 + 2 Combine:**
# ```
# Customer: "Find running headphones under $150"
#
# Part 1 → Semantic search with pgvector
# Part 2 → Custom tools return structured JSON
# Result → 15x cost reduction + consistent business logic
# ```
#
# ---
#
# ## Next Steps
#
# **Part 3: Multi-Agent Orchestration (25 min)**
# - Implement "Agents as Tools" pattern
# - Build specialist agents (Inventory, Pricing, Recommendations)
# - Coordinate agents with shared session state
# - Complete production-ready agentic system
#
# **What you'll learn:**
# - Agent hierarchies and delegation
# - Tool chaining and composition
# - Error handling in multi-agent systems
# - Production deployment patterns
#
# <div style="background: linear-gradient(135deg, #581c87 0%, #7c3aed 100%);
#             padding: 20px; border-radius: 10px; color: white; margin: 20px 0; text-align: center;">
#     <p style="margin: 0; font-size: 1.1em; font-weight: 600;">
#         🚀 Ready to orchestrate multiple agents?
#     </p>
#     <p style="margin: 12px 0 0 0; font-size: 1.05em;">
#         Open <code style="background: rgba(255,255,255,0.2); padding: 4px 12px; border-radius: 6px;">Part_3_Multi_Agent_Orchestration.ipynb</code>
#     </p>
# </div>
#
# ---
#
# <div style="text-align: center; color: #888; font-size: 0.9em; margin-top: 30px;">
# Built for AWS re:Invent 2025 | DAT406 Workshop
# </div>
